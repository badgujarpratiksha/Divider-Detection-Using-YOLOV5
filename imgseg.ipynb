# %% [markdown]
# <a href="https://colab.research.google.com/github/badgujarpratiksha/Divider-Detection-Using-YOLOV5/blob/main/imgseg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cfg = 'yolov8x-seg_custom.yaml'

# %%
#For drivr connection
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#ultraylics installation
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 699.8/699.8 kB 7.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

import os


model = YOLO('yolov8n-seg.pt')    # load a pretrained model (recommended for training)

results = model.train(data="/content/drive/MyDrive/Colab Notebooks/seg_divider/custom_data.yaml", epochs=25, workers=1, batch=8,imgsz=640,boxes=False)
# Out:
# ...
# 100%|██████████| 6.73M/6.73M [00:00<00:00, 129MB/s]
# WARNING ⚠️ 'boxes' is deprecated and will be removed in 'ultralytics 8.299999999999999' in the future. Please use 'show_boxes' instead.
# Ultralytics YOLOv8.1.0 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !scp -r /content/runs '/content/drive/MyDrive/Colab Notebooks/seg_divider'

# %%
from ultralytics import YOLO

import os

# !yolo task=segment boxes=False mode=predict model="/content/drive/MyDrive/Colab Notebooks/seg_divider/runs/segment/train/weights/last.pt" source="/content/drive/MyDrive/Colab Notebooks/seg_divider/custom_dataset/test/test_Vid[1].mp4" save=true
#forfolder !yolo task=segment mode=predict model="/content/runs/segment/train2/weights/last.pt" source="/content/drive/MyDrive/Colab Notebooks/seg_divider/custom_dataset/valid"
#foroneimage !yolo task=segment mode=predict model=runs/segment/train/weights/best.pt source="test_data/1 (1).jpg"
#forvideo    !yolo task=segment mode=predict model=runs/segment/train/weights/best.pt source="test_data/Keyboard.mp4"
#forcamera   !yolo task=segment mode=predict model=runs/segment/train/weights/best.pt source=0
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (6121/11117) /content/drive/MyDrive/Colab Notebooks/seg_divider/custom_dataset/test/test_Vid[1].mp4: 384x640 2 dividers, 10.7ms
# video 1/1 (6122/11117) /content/drive/MyDrive/Colab Notebooks/seg_divider/custom_dataset/test/test_Vid[1].mp4: 384x640 2 dividers, 10.5ms
# video 1/1 (6123/11117) /content/drive/MyDrive/Colab Notebooks/seg_divider/custom_dataset/test/test_Vid[1].mp4: 384x640 2 dividers, 14.4ms
# video 1/1 (6124/11117) /content/drive/MyDrive/Colab Notebooks/seg_divider/custom_dataset/test/test_Vid[1].mp4: 384x640 2 dividers, 12.6ms
# video 1/1 (6125/11117) /content/drive/MyDrive/Colab Notebooks/seg_divider/custom_dataset/test/test_Vid[1].mp4: 384x640 2 dividers, 9.0ms
# video 1/1 (6126/11117) /content/drive/MyDrive/Colab Notebooks/seg_divider/custom_dataset/test/test_Vid[1].mp4: 384x640 2 dividers, 18.6ms
# ...

# %%
# !scp -r /content/runs/segment/predict/test_Vid[1].avi '/content/drive/MyDrive/Colab Notebooks'
